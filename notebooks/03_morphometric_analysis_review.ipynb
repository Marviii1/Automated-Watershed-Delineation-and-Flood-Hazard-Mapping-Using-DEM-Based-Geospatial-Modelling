# %% [markdown]
# # Morphometric Analysis Review
# Inspect morphometric tables after script 07.

# %%
import pandas as pd
from src.config import load_config_bundle, resolve_path
configs = load_config_bundle('config')
path = resolve_path(configs['data']['processed']['subbasin_morphometry_csv'])
pd.read_csv(path).head() if path.exists() else print('Run script 07 first')

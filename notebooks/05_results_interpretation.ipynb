# %% [markdown]
# # Results Interpretation
# Use this notebook to compare morphometry, hazard summaries, and sub-basin priority rankings.

# %%
import pandas as pd
from src.config import load_config_bundle, resolve_path
configs = load_config_bundle('config')
priority = resolve_path(configs['data']['processed']['subbasin_priority_csv'])
pd.read_csv(priority).sort_values('priority_rank').head(10) if priority.exists() else print('Run script 11 first')

# %% [markdown]
# # Hydrology Outputs Review
# Use this notebook after running scripts 03-06.

# %%
from pathlib import Path
from src.config import load_config_bundle, resolve_path
configs = load_config_bundle('config')
for key in ['corrected_dem','flow_direction','flow_accumulation','stream_raster']:
    p = resolve_path(configs['data']['interim'][key])
    print(key, p, p.exists())

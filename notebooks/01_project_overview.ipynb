# %% [markdown]
# # Project Overview
# Lightweight notebook for reviewing configured project metadata after scripts are run.

# %%
from src.config import load_config_bundle
configs = load_config_bundle('config')
configs['project']

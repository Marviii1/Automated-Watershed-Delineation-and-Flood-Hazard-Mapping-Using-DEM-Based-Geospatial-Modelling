# %% [markdown]
# # Flood Hazard Review
# Inspect flood hazard tables after scripts 09-10.

# %%
import pandas as pd
from src.config import load_config_bundle, resolve_path
configs = load_config_bundle('config')
path = resolve_path(configs['data']['processed']['hazard_area_summary_csv'])
pd.read_csv(path) if path.exists() else print('Run script 10 first')
